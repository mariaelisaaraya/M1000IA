# %% [markdown]
# #EDA del archivo de metadatos ya filtrado que corresponde al dataset Skin Cancer(PAD-UFES-20)
#  https://www.kaggle.com/datasets/mahdavi1202/skin-cancer/data

# %% [markdown]
# ###Instalación paquetes necessarios

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /Users/edgardocrovetto/anaconda3/lib/python3.11/site-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/edgardocrovetto/anaconda3/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/edgardocrovetto/anaconda3/lib/python3.11/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/edgardocrovetto/anaconda3/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in /Users/edgardocrovetto/anaconda3/lib/python3.11/site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in /Users/edgardocrovetto/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
# !pip3 install pandas matplotlib seaborn scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /Users/edgardocrovetto/Library/Python/3.9/lib/python/site-packages (2.2.3)
# Requirement already satisfied: matplotlib in /Users/edgardocrovetto/Library/Python/3.9/lib/python/site-packages (3.9.2)
# Requirement already satisfied: seaborn in /Users/edgardocrovetto/Library/Python/3.9/lib/python/site-packages (0.13.2)
# Requirement already satisfied: scikit-learn in /Users/edgardocrovetto/Library/Python/3.9/lib/python/site-packages (1.5.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/edgardocrovetto/Library/Python/3.9/lib/python/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/edgardocrovetto/Library/Python/3.9/lib/python/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/edgardocrovetto/Library/Python/3.9/lib/python/site-packages (from pandas) (2024.2)
# Requirement already satisfied: numpy>=1.22.4 in /Users/edgardocrovetto/Library/Python/3.9/lib/python/site-packages (from pandas) (2.0.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/edgardocrovetto/Library/Python/3.9/lib/python/site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: cycler>=0.10 in /Users/edgardocrovetto/Library/Python/3.9/lib/python/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: pillow>=8 in /Users/edgardocrovetto/Library/Python/3.9/lib/python/site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/edgardocrovetto/Library/Python/3.9/lib/python/site-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/edgardocrovetto/Library/Python/3.9/lib/python/site-packages (from matplotlib) (6.4.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/edgardocrovetto/Library/Python/3.9/lib/python/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/edgardocrovetto/Library/Python/3.9/lib/python/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: packaging>=20.0 in /Users/edgardocrovetto/Library/Python/3.9/lib/python/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: joblib>=1.2.0 in /Users/edgardocrovetto/Library/Python/3.9/lib/python/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: scipy>=1.6.0 in /Users/edgardocrovetto/Library/Python/3.9/lib/python/site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/edgardocrovetto/Library/Python/3.9/lib/python/site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: zipp>=3.1.0 in /Users/edgardocrovetto/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.17.0)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.15.0)
# WARNING: You are using pip version 21.2.4; however, version 24.2 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ###Carga de dataset

# %% [markdown]
# ### EDA dataset completo

# %%
# Archivo CSV con los datos
file = "metadatos_actualizados_limpios_normalizados.csv"

# Leer el archivo CSV desde la URL
df = pd.read_csv(file)

# Primeras filas del dataset
print("\nPrimeras 5 filas del dataset:")
print(df.head())

# Nombres de las columnas
print("\nNombres de las columnas:")
print(df.columns)

# Verificar los tipos de datos de cada columna
print("\nTipos de datos por columna:")
print(df.dtypes)


# Dimensiones del dataset (filas, columnas)
print("\nDimensiones del dataset (filas, columnas):")
print(df.shape)

# Información general del dataset
print("\nInformación general del dataset:")
print(df.info())

# Estadísticas descriptivas de las columnas numéricas
print("\nEstadísticas descriptivas:")
print(df.describe())

# Estadísticas descriptivas para todas las columnas (numéricas y categóricas)
print("\nEstadísticas descriptivas para todas las columnas:")
print(df.describe(include='all'))
# Out:
# Primeras 5 filas del dataset:
#      lesion_id          image_id   dx   age     sex     localization  \
# 0  ham_0003577  isic_0024307.jpg   nv  50.0    male  lower extremity
# 1  ham_0000484  isic_0024309.jpg   nv  40.0    male            trunk
# 2  ham_0003350  isic_0024310.jpg  mel  60.0    male            chest
# 3  ham_0001359  isic_0024312.jpg  bkl  75.0    male  lower extremity
# 4  ham_0002869  isic_0024313.jpg  mel  50.0  female             back
#
#    classification   dataset
# 0  lesión benigna  original
# 1  lesión benigna  original
# 2  lesión maligna  original
# 3  lesión benigna  original
# 4  lesión maligna  original
#
# Nombres de las columnas:
# Index(['lesion_id', 'image_id', 'dx', 'age', 'sex', 'localization',
#        'classification', 'dataset'],
#       dtype='object')
#
# Tipos de datos por columna:
# lesion_id          object
# image_id           object
# dx                 object
# age               float64
# sex                object
# localization       object
# classification     object
# dataset            object
# dtype: object
#
# Dimensiones del dataset (filas, columnas):
# (6021, 8)
#
# Información general del dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6021 entries, 0 to 6020
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   lesion_id       6021 non-null   object
#  1   image_id        6021 non-null   object
#  2   dx              6021 non-null   object
#  3   age             6021 non-null   float64
#  4   sex             6021 non-null   object
#  5   localization    6021 non-null   object
#  6   classification  6021 non-null   object
#  7   dataset         6021 non-null   object
# dtypes: float64(1), object(7)
# memory usage: 376.4+ KB
# None
#
# Estadísticas descriptivas:
#                age
# count  6021.000000
# mean     56.820130
# std      16.606288
# min       0.000000
# 25%      45.000000
# 50%      55.000000
# 75%      70.000000
# max      94.000000
#
# Estadísticas descriptivas para todas las columnas:
#           lesion_id          image_id    dx          age   sex localization  \
# count          6021              6021  6021  6021.000000  6021         6021
# unique         4547              6021     5          NaN     2           19
# top     ham_0000835  isic_0024307.jpg    nv          NaN  male         back
# freq              6                 1  2391          NaN  3320         1355
# mean            NaN               NaN   NaN    56.820130   NaN          NaN
# std             NaN               NaN   NaN    16.606288   NaN          NaN
# min             NaN               NaN   NaN     0.000000   NaN          NaN
# 25%             NaN               NaN   NaN    45.000000   NaN          NaN
# 50%             NaN               NaN   NaN    55.000000   NaN          NaN
# 75%             NaN               NaN   NaN    70.000000   NaN          NaN
# max             NaN               NaN   NaN    94.000000   NaN          NaN
#
#         classification   dataset
# count             6021      6021
# unique               2         2
# top     lesión benigna  original
# freq              3514      5077
# mean               NaN       NaN
# std                NaN       NaN
# min                NaN       NaN
# 25%                NaN       NaN
# 50%                NaN       NaN
# 75%                NaN       NaN
# max                NaN       NaN

# %%
# Contar valores únicos por cada columna
print("\nValores únicos por columna:")
valores_unicos = df.nunique()
print(valores_unicos)

# Graficar el conteo de valores únicos en columnas categóricas y mostrar valores por escrito
for col in df.select_dtypes(include=['object']).columns:
    print(f"\nColumna: {col}")
    print(f"Valores únicos: {df[col].nunique()}")
    print(f"Conteo de cada valor en '{col}':")
    print(df[col].value_counts())

    # Graficar el conteo de valores
    plt.figure(figsize=(10, 5))
    sns.countplot(y=col, data=df, order=df[col].value_counts().index, palette='Set2')
    plt.title(f"Conteo de valores en {col}")
    plt.xlabel("Frecuencia")
    plt.ylabel(col)
    plt.show()
# Out:
# Valores únicos por columna:
# lesion_id         4547
# image_id          6021
# dx                   5
# age                 72
# sex                  2
# localization        19
# classification       2
# dataset              2
# dtype: int64
#
# Columna: lesion_id
# Valores únicos: 4547
# Conteo de cada valor en 'lesion_id':
# lesion_id
# ham_0000835    6
# ham_0001863    6
# ham_0003789    6
# ham_0007427    5
# ham_0007343    5
#               ..
# ham_0000142    1
# ham_0003726    1
# ham_0001607    1
# ham_0002835    1
# 153.0          1
# Name: count, Length: 4547, dtype: int64
# /var/folders/h5/dtm5gnts0zn8dkbwtc10wgn80000gn/T/ipykernel_47666/3417591974.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=col, data=df, order=df[col].value_counts().index, palette='Set2')
# Columna: image_id
# Valores únicos: 6021
# Conteo de cada valor en 'image_id':
# image_id
# isic_0024307.jpg      1
# isic_0032372.jpg      1
# isic_0032386.jpg      1
# isic_0032384.jpg      1
# isic_0032382.jpg      1
#                      ..
# isic_0028410.jpg      1
# isic_0028404.jpg      1
# isic_0028403.jpg      1
# isic_0028398.jpg      1
# pat_99_153_636.jpg    1
# Name: count, Length: 6021, dtype: int64
# /var/folders/h5/dtm5gnts0zn8dkbwtc10wgn80000gn/T/ipykernel_47666/3417591974.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=col, data=df, order=df[col].value_counts().index, palette='Set2')
# Columna: dx
# Valores únicos: 5
# Conteo de cada valor en 'dx':
# dx
# nv     2391
# bcc    1354
# mel    1153
# bkl    1076
# sek      47
# Name: count, dtype: int64
# /var/folders/h5/dtm5gnts0zn8dkbwtc10wgn80000gn/T/ipykernel_47666/3417591974.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=col, data=df, order=df[col].value_counts().index, palette='Set2')
# Columna: sex
# Valores únicos: 2
# Conteo de cada valor en 'sex':
# sex
# male      3320
# female    2701
# Name: count, dtype: int64
# /var/folders/h5/dtm5gnts0zn8dkbwtc10wgn80000gn/T/ipykernel_47666/3417591974.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=col, data=df, order=df[col].value_counts().index, palette='Set2')
# Columna: localization
# Valores únicos: 19
# Conteo de cada valor en 'localization':
# localization
# back               1355
# lower extremity     972
# face                847
# upper extremity     617
# trunk               591
# abdomen             426
# chest               408
# neck                155
# foot                147
# nose                123
# scalp                79
# ear                  74
# forearm              74
# hand                 57
# arm                  52
# thigh                19
# genital              14
# lip                  10
# acral                 1
# Name: count, dtype: int64
# /var/folders/h5/dtm5gnts0zn8dkbwtc10wgn80000gn/T/ipykernel_47666/3417591974.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=col, data=df, order=df[col].value_counts().index, palette='Set2')
# Columna: classification
# Valores únicos: 2
# Conteo de cada valor en 'classification':
# classification
# lesión benigna    3514
# lesión maligna    2507
# Name: count, dtype: int64
# /var/folders/h5/dtm5gnts0zn8dkbwtc10wgn80000gn/T/ipykernel_47666/3417591974.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=col, data=df, order=df[col].value_counts().index, palette='Set2')
# Columna: dataset
# Valores únicos: 2
# Conteo de cada valor en 'dataset':
# dataset
# original    5077
# extra        944
# Name: count, dtype: int64
# /var/folders/h5/dtm5gnts0zn8dkbwtc10wgn80000gn/T/ipykernel_47666/3417591974.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=col, data=df, order=df[col].value_counts().index, palette='Set2')

# %%
# Mostrar las etiquetas (nombres de las columnas) del DataFrame
print("Etiquetas (nombres de las columnas) del dataset:")
print(df.columns.tolist())

# Identificar las columnas numéricas
columnas_numericas = df.select_dtypes(include=['float64', 'int64']).columns.tolist()
cantidad_numericas = len(columnas_numericas)
print("\nCantidad de columnas numéricas:", cantidad_numericas)
print("Columnas numéricas en el dataset:")
print(columnas_numericas)

# Identificar las columnas no numéricas
columnas_no_numericas = df.select_dtypes(exclude=['float64', 'int64']).columns.tolist()
cantidad_no_numericas = len(columnas_no_numericas)
print("\nCantidad de columnas no numéricas:", cantidad_no_numericas)
print("Columnas no numéricas en el dataset:")
print(columnas_no_numericas)

# Calcular la correlación solo entre columnas numéricas
if columnas_numericas:
    correlacion = df[columnas_numericas].corr()
    print("\nMatriz de correlación entre las columnas numéricas:")
    print(correlacion)

    # Mostrar el mapa de calor de correlación
    plt.figure(figsize=(10, 6))
    sns.heatmap(correlacion, annot=True, cmap='coolwarm', fmt=".2f")
    plt.title("Mapa de calor de la correlación")
    plt.show()
else:
    print("\nNo hay columnas numéricas para calcular la correlación.")

# Guardar los resultados en un archivo de texto
with open('resultados_columnas.txt', 'w') as f:
    # Escribir resultados en el archivo
    f.write("Etiquetas (nombres de las columnas) del dataset:\n")
    f.write(str(df.columns.tolist()) + "\n")

    f.write("\nCantidad de columnas numéricas: {}\n".format(cantidad_numericas))
    f.write("Columnas numéricas en el dataset:\n")
    f.write(str(columnas_numericas) + "\n")

    f.write("\nCantidad de columnas no numéricas: {}\n".format(cantidad_no_numericas))
    f.write("Columnas no numéricas en el dataset:\n")
    f.write(str(columnas_no_numericas) + "\n")

    if columnas_numericas:
        f.write("\nMatriz de correlación entre las columnas numéricas:\n")
        f.write(str(correlacion) + "\n")
# Out:
# Etiquetas (nombres de las columnas) del dataset:
# ['lesion_id', 'image_id', 'dx', 'age', 'sex', 'localization', 'classification', 'dataset']
#
# Cantidad de columnas numéricas: 1
# Columnas numéricas en el dataset:
# ['age']
#
# Cantidad de columnas no numéricas: 7
# Columnas no numéricas en el dataset:
# ['lesion_id', 'image_id', 'dx', 'sex', 'localization', 'classification', 'dataset']
#
# Matriz de correlación entre las columnas numéricas:
#      age
# age  1.0

# %%
# Mostrar la descripción estadística de las columnas numéricas
descripcion = df.describe()
print("\nDescripción estadística de las columnas numéricas:")
print(descripcion)

# Generar histogramas para todas las columnas numéricas
df.hist(figsize=(10, 6), bins=30, color='c', alpha=0.75)
plt.suptitle("Distribución de datos")
plt.show()
# Out:
# Descripción estadística de las columnas numéricas:
#                age
# count  6021.000000
# mean     56.820130
# std      16.606288
# min       0.000000
# 25%      45.000000
# 50%      55.000000
# 75%      70.000000
# max      94.000000

# %%
# Mostrar la descripción estadística de las columnas numéricas
descripcion = df.describe()
print("\nDescripción estadística de las columnas numéricas:")
print(descripcion)

# Crear boxplots para detectar valores atípicos en columnas numéricas
plt.figure(figsize=(12, 8))
sns.boxplot(data=df.select_dtypes(include=['float64', 'int64']))
plt.title("Distribución de variables numéricas (Boxplot)")
plt.xticks(rotation=90)  # Rotar etiquetas de columnas si hay muchas
plt.show()
# Out:
# Descripción estadística de las columnas numéricas:
#                age
# count  6021.000000
# mean     56.820130
# std      16.606288
# min       0.000000
# 25%      45.000000
# 50%      55.000000
# 75%      70.000000
# max      94.000000

# %%
#Distribución de imagenes según tipo de lesión

# Agrupar por tipo de lesion  y contar las lesiones
lesiones_por_tipo = df.groupby('dx').size().reset_index(name='cantidad_de_lesiones')

# Mostrar la tabla resultante
print(lesiones_por_tipo)
# Out:
#     dx  cantidad_de_lesiones
# 0  bcc                  1354
# 1  bkl                  1076
# 2  mel                  1153
# 3   nv                  2391
# 4  sek                    47

# %%
#Graficar las lesiones por tipo
# Crear un gráfico de barras con seaborn
plt.figure(figsize=(10, 6))  # Establece el tamaño del gráfico
sns.barplot(x='dx', y='cantidad_de_lesiones', data=lesiones_por_tipo, palette='Blues_d')

# Añadir títulos y etiquetas
plt.title('Cantidad de Lesiones por Tipo de lesión', fontsize=16)
plt.xlabel('Categoría de Lesión', fontsize=12)
plt.ylabel('Cantidad de Lesiones', fontsize=12)

# Rotar las etiquetas del eje x si es necesario
plt.xticks(rotation=45, ha='right')

# Mostrar el gráfico
plt.tight_layout()
plt.show()
# Out:
# /var/folders/h5/dtm5gnts0zn8dkbwtc10wgn80000gn/T/ipykernel_47666/384163199.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='dx', y='cantidad_de_lesiones', data=lesiones_por_tipo, palette='Blues_d')

# %% [markdown]
# ### Verificar si el dataset filtrado tiene valores nulos y/o duplicados

# %%
# ver cantidad de valores nulos
nulos_por_columna = df.isnull().sum()
print("Cantidad de valores nulos por columna")
print(nulos_por_columna)

#ver cantidad de filas duplicadas
duplicados = df.duplicated().sum()
print(f"Cantidad de filas duplicadas: {duplicados}")
# Out:
# Cantidad de valores nulos por columna
# lesion_id         0
# image_id          0
# dx                0
# age               0
# sex               0
# localization      0
# classification    0
# dataset           0
# dtype: int64
# Cantidad de filas duplicadas: 0
